# %% [markdown]
# ## 📊 Data Analysis

# %%
import sys
from pathlib import Path

parent_dir = str(Path().resolve().parent)

if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import main

# %%
main.analysis()
# Out:
# 2026-02-25 03:42:11,355-INFO-The describe of numeric column price was obtained correctly
# 2026-02-25 03:42:11,356-INFO-price: positive (media=9000.00)
# 2026-02-25 03:42:11,356-INFO-Histogram plot for column "price" was created
# -- Basic EDA --
#
# -- Frame Visualization --
# shape: (10, 13)
# ┌───────┬────────────┬─────────────┬───────────┬───┬────────────┬────────┬────────────┬────────────┐
# │ price ┆ model_year ┆ model       ┆ condition ┆ … ┆ paint_colo ┆ is_4wd ┆ date_poste ┆ days_liste │
# │ ---   ┆ ---        ┆ ---         ┆ ---       ┆   ┆ r          ┆ ---    ┆ d          ┆ d          │
# │ i64   ┆ f64        ┆ str         ┆ str       ┆   ┆ ---        ┆ f64    ┆ ---        ┆ ---        │
# │       ┆            ┆             ┆           ┆   ┆ str        ┆        ┆ str        ┆ i64        │
# ╞═══════╪════════════╪═════════════╪═══════════╪═══╪════════════╪════════╪════════════╪════════════╡
# │ 9400  ┆ 2011.0     ┆ bmw x5      ┆ good      ┆ … ┆ null       ┆ 1.0    ┆ 2018-06-23 ┆ 19         │
# │ 25500 ┆ null       ┆ ford f-150  ┆ good      ┆ … ┆ white      ┆ 1.0    ┆ 2018-10-19 ┆ 50         │
# │ 5500  ┆ 2013.0     ┆ hyundai     ┆ like new  ┆ … ┆ red        ┆ null   ┆ 2019-02-07 ┆ 79         │
# │       ┆            ┆ sonata      ┆           ┆   ┆            ┆        ┆            ┆            │
# │ 1500  ┆ 2003.0     ┆ ford f-150  ┆ fair      ┆ … ┆ null       ┆ null   ┆ 2019-03-22 ┆ 9          │
# │ 14900 ┆ 2017.0     ┆ chrysler    ┆ excellent ┆ … ┆ black      ┆ null   ┆ 2019-04-02 ┆ 28         │
# │       ┆            ┆ 200         ┆           ┆   ┆            ┆        ┆            ┆            │
# │ 14990 ┆ 2014.0     ┆ chrysler    ┆ excellent ┆ … ┆ black      ┆ 1.0    ┆ 2018-06-20 ┆ 15         │
# │       ┆            ┆ 300         ┆           ┆   ┆            ┆        ┆            ┆            │
# │ 12990 ┆ 2015.0     ┆ toyota      ┆ excellent ┆ … ┆ white      ┆ null   ┆ 2018-12-27 ┆ 73         │
# │       ┆            ┆ camry       ┆           ┆   ┆            ┆        ┆            ┆            │
# │ 15990 ┆ 2013.0     ┆ honda pilot ┆ excellent ┆ … ┆ black      ┆ 1.0    ┆ 2019-01-07 ┆ 68         │
# │ 11500 ┆ 2012.0     ┆ kia sorento ┆ excellent ┆ … ┆ null       ┆ 1.0    ┆ 2018-07-16 ┆ 19         │
# │ 9200  ┆ 2008.0     ┆ honda pilot ┆ excellent ┆ … ┆ blue       ┆ 1.0    ┆ 2019-02-15 ┆ 17         │
# └───────┴────────────┴─────────────┴───────────┴───┴────────────┴────────┴────────────┴────────────┘
#
# -- Frame Shape --
# columns: 13, rows: 51525
#
# -- Existing Columns --
# Column: price
# Datatype: Int64
# Column: model_year
# Datatype: Float64
# Column: model
# Datatype: String
# Column: condition
# Datatype: String
# Column: cylinders
# Datatype: Int64
# Column: fuel
# Datatype: String
# Column: odometer
# Datatype: Float64
# Column: transmission
# Datatype: String
# Column: type
# Datatype: String
# Column: paint_color
# Datatype: String
# Column: is_4wd
# Datatype: Float64
# Column: date_posted
# Datatype: String
# Column: days_listed
# Datatype: Int64
#
# -- Basic Descriptive Statistics --
# shape: (9, 14)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ statistic  ┆ price     ┆ model_yea ┆ model     ┆ … ┆ paint_col ┆ is_4wd  ┆ date_post ┆ days_list │
# │ ---        ┆ ---       ┆ r         ┆ ---       ┆   ┆ or        ┆ ---     ┆ ed        ┆ ed        │
# │ str        ┆ f64       ┆ ---       ┆ str       ┆   ┆ ---       ┆ f64     ┆ ---       ┆ ---       │
# │            ┆           ┆ f64       ┆           ┆   ┆ str       ┆         ┆ str       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ count      ┆ 51525.0   ┆ 47906.0   ┆ 51525     ┆ … ┆ 42258     ┆ 25572.0 ┆ 51525     ┆ 51525.0   │
# │ null_count ┆ 0.0       ┆ 3619.0    ┆ 0         ┆ … ┆ 9267      ┆ 25953.0 ┆ 0         ┆ 0.0       │
# │ mean       ┆ 12132.464 ┆ 2009.7504 ┆ null      ┆ … ┆ null      ┆ 1.0     ┆ null      ┆ 39.55476  │
# │            ┆ 92        ┆ 7         ┆           ┆   ┆           ┆         ┆           ┆           │
# │ std        ┆ 10040.803 ┆ 6.282065  ┆ null      ┆ … ┆ null      ┆ 0.0     ┆ null      ┆ 28.20427  │
# │            ┆ 015       ┆           ┆           ┆   ┆           ┆         ┆           ┆           │
# │ min        ┆ 1.0       ┆ 1908.0    ┆ acura tl  ┆ … ┆ black     ┆ 1.0     ┆ 2018-05-0 ┆ 0.0       │
# │            ┆           ┆           ┆           ┆   ┆           ┆         ┆ 1         ┆           │
# │ 25%        ┆ 5000.0    ┆ 2006.0    ┆ null      ┆ … ┆ null      ┆ 1.0     ┆ null      ┆ 19.0      │
# │ 50%        ┆ 9000.0    ┆ 2011.0    ┆ null      ┆ … ┆ null      ┆ 1.0     ┆ null      ┆ 33.0      │
# │ 75%        ┆ 16839.0   ┆ 2014.0    ┆ null      ┆ … ┆ null      ┆ 1.0     ┆ null      ┆ 53.0      │
# │ max        ┆ 375000.0  ┆ 2019.0    ┆ volkswage ┆ … ┆ yellow    ┆ 1.0     ┆ 2019-04-1 ┆ 271.0     │
# │            ┆           ┆           ┆ n passat  ┆   ┆           ┆         ┆ 9         ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴───────────┴─────────┴───────────┴───────────┘
#
# -- Total Null Values --
# Total nulls: shape: (1, 13)
# ┌───────┬────────────┬───────┬───────────┬───┬─────────────┬────────┬─────────────┬─────────────┐
# │ price ┆ model_year ┆ model ┆ condition ┆ … ┆ paint_color ┆ is_4wd ┆ date_posted ┆ days_listed │
# │ ---   ┆ ---        ┆ ---   ┆ ---       ┆   ┆ ---         ┆ ---    ┆ ---         ┆ ---         │
# │ u32   ┆ u32        ┆ u32   ┆ u32       ┆   ┆ u32         ┆ u32    ┆ u32         ┆ u32         │
# ╞═══════╪════════════╪═══════╪═══════════╪═══╪═════════════╪════════╪═════════════╪═════════════╡
# │ 0     ┆ 3619       ┆ 0     ┆ 0         ┆ … ┆ 9267        ┆ 25953  ┆ 0           ┆ 0           │
# └───────┴────────────┴───────┴───────────┴───┴─────────────┴────────┴─────────────┴─────────────┘
# 2026-02-25 03:42:11,550-INFO-The insights from the data for the numeric column price have been obtained correctly
# 2026-02-25 03:42:11,581-INFO-The describe of numeric column model_year was obtained correctly
# 2026-02-25 03:42:11,582-INFO-model_year: negative (media=2011.00)
# 2026-02-25 03:42:11,582-INFO-Histogram plot for column "model_year" was created
# 2026-02-25 03:42:11,622-INFO-The insights from the data for the numeric column model_year have been obtained correctly
# 2026-02-25 03:42:11,651-INFO-The unique data value for column model was obtained correctly
# 2026-02-25 03:42:11,652-INFO-100 values for the column model
# 2026-02-25 03:42:11,652-INFO-Bar plot for column "model" was created
# 2026-02-25 03:42:11,690-INFO-The insights from the data for the categoric column model have been obtained correctly
# 2026-02-25 03:42:11,719-INFO-The unique data value for column condition was obtained correctly
# 2026-02-25 03:42:11,719-INFO-6 values for the column condition
# 2026-02-25 03:42:11,720-INFO-Bar plot for column "condition" was created
# 2026-02-25 03:42:11,758-INFO-The insights from the data for the categoric column condition have been obtained correctly
# 2026-02-25 03:42:11,782-INFO-The describe of numeric column cylinders was obtained correctly
# 2026-02-25 03:42:11,782-INFO-cylinders: positive (media=6.00)
# 2026-02-25 03:42:11,783-INFO-Histogram plot for column "cylinders" was created
# 2026-02-25 03:42:11,822-INFO-The insights from the data for the numeric column cylinders have been obtained correctly
# 2026-02-25 03:42:11,850-INFO-The unique data value for column fuel was obtained correctly
# 2026-02-25 03:42:11,850-INFO-5 values for the column fuel
# 2026-02-25 03:42:11,851-INFO-Bar plot for column "fuel" was created
# 2026-02-25 03:42:11,888-INFO-The insights from the data for the categoric column fuel have been obtained correctly
# 2026-02-25 03:42:11,912-INFO-The describe of numeric column odometer was obtained correctly
# 2026-02-25 03:42:11,913-INFO-odometer: positive (media=113000.00)
# 2026-02-25 03:42:11,913-INFO-Histogram plot for column "odometer" was created
# 2026-02-25 03:42:11,952-INFO-The insights from the data for the numeric column odometer have been obtained correctly
# 2026-02-25 03:42:11,980-INFO-The unique data value for column transmission was obtained correctly
# 2026-02-25 03:42:11,981-INFO-3 values for the column transmission
# 2026-02-25 03:42:11,981-INFO-Bar plot for column "transmission" was created
# 2026-02-25 03:42:12,018-INFO-The insights from the data for the categoric column transmission have been obtained correctly
# 2026-02-25 03:42:12,041-INFO-The unique data value for column type was obtained correctly
# 2026-02-25 03:42:12,041-INFO-13 values for the column type
# 2026-02-25 03:42:12,042-INFO-Bar plot for column "type" was created
# 2026-02-25 03:42:12,079-INFO-The insights from the data for the categoric column type have been obtained correctly
# 2026-02-25 03:42:12,104-INFO-The unique data value for column paint_color was obtained correctly
# 2026-02-25 03:42:12,105-INFO-13 values for the column paint_color
# 2026-02-25 03:42:12,105-INFO-Bar plot for column "paint_color" was created
# 2026-02-25 03:42:12,141-INFO-The insights from the data for the categoric column paint_color have been obtained correctly
# 2026-02-25 03:42:12,165-INFO-The describe of numeric column is_4wd was obtained correctly
# 2026-02-25 03:42:12,166-INFO-is_4wd: simetrico (media=1.00)
# 2026-02-25 03:42:12,166-INFO-Histogram plot for column "is_4wd" was created
# 2026-02-25 03:42:12,206-INFO-The insights from the data for the numeric column is_4wd have been obtained correctly
# 2026-02-25 03:42:12,236-INFO-The unique data value for column date_posted was obtained correctly
# 2026-02-25 03:42:12,237-INFO-354 values for the column date_posted
# 2026-02-25 03:42:12,237-INFO-Bar plot for column "date_posted" was created
# 2026-02-25 03:42:12,274-INFO-The insights from the data for the categoric column date_posted have been obtained correctly
# 2026-02-25 03:42:12,298-INFO-The describe of numeric column days_listed was obtained correctly
# 2026-02-25 03:42:12,299-INFO-days_listed: positive (media=33.00)
# 2026-02-25 03:42:12,300-INFO-Histogram plot for column "days_listed" was created
# 2026-02-25 03:42:12,339-INFO-The insights from the data for the numeric column days_listed have been obtained correctly
# 2026-02-25 03:42:12,368-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column price were obtained correctly
# 2026-02-25 03:42:12,368-INFO-price: 3.19% outliers
# 2026-02-25 03:42:12,369-INFO-Scatter plot for column "price" was created
# 2026-02-25 03:42:12,404-INFO-The insights from the outlier data for the column price have been obtained correctly
# 2026-02-25 03:42:12,432-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column model_year were obtained correctly
# 2026-02-25 03:42:12,434-INFO-model_year: 1.38% outliers
# 2026-02-25 03:42:12,435-INFO-Scatter plot for column "model_year" was created
# 2026-02-25 03:42:12,469-INFO-The insights from the outlier data for the column model_year have been obtained correctly
# 2026-02-25 03:42:12,499-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column cylinders were obtained correctly
# 2026-02-25 03:42:12,501-INFO-cylinders: 0.00% outliers
# 2026-02-25 03:42:12,502-WARNING-The number of outliers is 0, so it is not necessary to make a boxplot for column cylinders
# 2026-02-25 03:42:12,502-INFO-The insights from the outlier data for the column cylinders have been obtained correctly
# 2026-02-25 03:42:12,502-WARNING-The plot for the column cylinders was not saved because save_plots is False
# 2026-02-25 03:42:12,509-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column odometer were obtained correctly
# 2026-02-25 03:42:12,509-INFO-odometer: 0.95% outliers
# 2026-02-25 03:42:12,510-INFO-Scatter plot for column "odometer" was created
# 2026-02-25 03:42:12,544-INFO-The insights from the outlier data for the column odometer have been obtained correctly
# 2026-02-25 03:42:12,572-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column is_4wd were obtained correctly
# 2026-02-25 03:42:12,573-INFO-is_4wd: 0.00% outliers
# 2026-02-25 03:42:12,574-WARNING-The number of outliers is 0, so it is not necessary to make a boxplot for column is_4wd
# 2026-02-25 03:42:12,574-INFO-The insights from the outlier data for the column is_4wd have been obtained correctly
# 2026-02-25 03:42:12,575-WARNING-The plot for the column is_4wd was not saved because save_plots is False
# 2026-02-25 03:42:12,581-INFO-The frame with outliers (if applicable), the number of filtered outliers, and the percentage of total outliers for column days_listed were obtained correctly
# 2026-02-25 03:42:12,582-INFO-days_listed: 3.14% outliers
# 2026-02-25 03:42:12,582-INFO-Scatter plot for column "days_listed" was created
# 2026-02-25 03:42:12,618-INFO-The insights from the outlier data for the column days_listed have been obtained correctly
# 2026-02-25 03:42:12,650-WARNING-The columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have zero standard deviation or is zero
# 2026-02-25 03:42:12,651-INFO-Correlation operation for columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] were obtained correctly. "col_a", "col_b" and "r_val" were obtained.
# 2026-02-25 03:42:12,652-INFO-Top correlation A: model_year, top correlation B: The columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have zero standard deviation or is zero, r_value: The columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have zero standard deviation or is zero
# 2026-02-25 03:42:12,652-WARNING-The correlation value is invalid. Correlation detected: The columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have zero standard deviation or is zero
# 2026-02-25 03:42:12,653-INFO-The insights from the correlation data for the columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have been obtained correctly
# 2026-02-25 03:42:12,653-WARNING-The plot for the column ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] was not saved because save_plots is False
# 2026-02-25 03:42:12,655-INFO-Categories dominance and rare categories for column model were obtained correctly
# 2026-02-25 03:42:12,656-INFO-model: top=
# shape: (10, 2)
# ┌────────────────────────────┬───────┐
# │ model                      ┆ count │
# │ ---                        ┆ ---   │
# │ str                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ ford f-150                 ┆ 2796  │
# │ chevrolet silverado 1500   ┆ 2171  │
# │ ram 1500                   ┆ 1750  │
# │ chevrolet silverado        ┆ 1271  │
# │ jeep wrangler              ┆ 1119  │
# │ ram 2500                   ┆ 1091  │
# │ toyota camry               ┆ 990   │
# │ honda accord               ┆ 964   │
# │ chevrolet silverado 2500hd ┆ 915   │
# │ gmc sierra 1500            ┆ 906   │
# └────────────────────────────┴───────┘
# 2026-02-25 03:42:12,656-INFO-model: 69 total rare categories
# 2026-02-25 03:42:12,657-INFO-The insights from the categorical data for the column model have been obtained correctly
# 2026-02-25 03:42:12,657-WARNING-The plot for the column model was not saved because save_plots is False
# 2026-02-25 03:42:12,659-INFO-Categories dominance and rare categories for column condition were obtained correctly
# 2026-02-25 03:42:12,660-INFO-condition: top=
# shape: (6, 2)
# ┌───────────┬───────┐
# │ condition ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ u32   │
# ╞═══════════╪═══════╡
# │ excellent ┆ 24773 │
# │ good      ┆ 20145 │
# │ like new  ┆ 4742  │
# │ fair      ┆ 1607  │
# │ new       ┆ 143   │
# │ salvage   ┆ 115   │
# └───────────┴───────┘
# 2026-02-25 03:42:12,660-INFO-condition: 2 total rare categories
# 2026-02-25 03:42:12,660-INFO-The insights from the categorical data for the column condition have been obtained correctly
# 2026-02-25 03:42:12,661-WARNING-The plot for the column condition was not saved because save_plots is False
# 2026-02-25 03:42:12,663-INFO-Categories dominance and rare categories for column fuel were obtained correctly
# 2026-02-25 03:42:12,663-INFO-fuel: top=
# shape: (5, 2)
# ┌──────────┬───────┐
# │ fuel     ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ gas      ┆ 47288 │
# │ diesel   ┆ 3714  │
# │ hybrid   ┆ 409   │
# │ other    ┆ 108   │
# │ electric ┆ 6     │
# └──────────┴───────┘
# 2026-02-25 03:42:12,664-INFO-fuel: 3 total rare categories
# 2026-02-25 03:42:12,664-INFO-The insights from the categorical data for the column fuel have been obtained correctly
# 2026-02-25 03:42:12,665-WARNING-The plot for the column fuel was not saved because save_plots is False
# 2026-02-25 03:42:12,666-INFO-Categories dominance and rare categories for column transmission were obtained correctly
# 2026-02-25 03:42:12,667-INFO-transmission: top=
# shape: (3, 2)
# ┌──────────────┬───────┐
# │ transmission ┆ count │
# │ ---          ┆ ---   │
# │ str          ┆ u32   │
# ╞══════════════╪═══════╡
# │ automatic    ┆ 46902 │
# │ manual       ┆ 2829  │
# │ other        ┆ 1794  │
# └──────────────┴───────┘
# 2026-02-25 03:42:12,667-INFO-transmission: 0 total rare categories
# 2026-02-25 03:42:12,668-INFO-The insights from the categorical data for the column transmission have been obtained correctly
# 2026-02-25 03:42:12,668-WARNING-The plot for the column transmission was not saved because save_plots is False
# 2026-02-25 03:42:12,670-INFO-Categories dominance and rare categories for column type were obtained correctly
# 2026-02-25 03:42:12,671-INFO-type: top=
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ type        ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ SUV         ┆ 12405 │
# │ truck       ┆ 12353 │
# │ sedan       ┆ 12154 │
# │ pickup      ┆ 6988  │
# │ coupe       ┆ 2303  │
# │ wagon       ┆ 1541  │
# │ mini-van    ┆ 1161  │
# │ hatchback   ┆ 1047  │
# │ van         ┆ 633   │
# │ convertible ┆ 446   │
# └─────────────┴───────┘
# 2026-02-25 03:42:12,671-INFO-type: 4 total rare categories
# 2026-02-25 03:42:12,672-INFO-The insights from the categorical data for the column type have been obtained correctly
# 2026-02-25 03:42:12,672-WARNING-The plot for the column type was not saved because save_plots is False
# 2026-02-25 03:42:12,674-INFO-Categories dominance and rare categories for column paint_color were obtained correctly
# 2026-02-25 03:42:12,675-INFO-paint_color: top=
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ paint_color ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ white       ┆ 10029 │
# │ null        ┆ 9267  │
# │ black       ┆ 7692  │
# │ silver      ┆ 6244  │
# │ grey        ┆ 5037  │
# │ blue        ┆ 4475  │
# │ red         ┆ 4421  │
# │ green       ┆ 1396  │
# │ brown       ┆ 1223  │
# │ custom      ┆ 1153  │
# └─────────────┴───────┘
# 2026-02-25 03:42:12,675-INFO-paint_color: 3 total rare categories
# 2026-02-25 03:42:12,676-INFO-The insights from the categorical data for the column paint_color have been obtained correctly
# 2026-02-25 03:42:12,676-WARNING-The plot for the column paint_color was not saved because save_plots is False
# 2026-02-25 03:42:12,679-INFO-Categories dominance and rare categories for column date_posted were obtained correctly
# 2026-02-25 03:42:12,679-INFO-date_posted: top=
# shape: (10, 2)
# ┌─────────────┬───────┐
# │ date_posted ┆ count │
# │ ---         ┆ ---   │
# │ str         ┆ u32   │
# ╞═════════════╪═══════╡
# │ 2019-03-17  ┆ 186   │
# │ 2019-01-05  ┆ 184   │
# │ 2018-09-20  ┆ 178   │
# │ 2019-03-11  ┆ 176   │
# │ 2018-10-09  ┆ 174   │
# │ 2018-08-05  ┆ 173   │
# │ 2019-04-10  ┆ 173   │
# │ 2019-03-28  ┆ 172   │
# │ 2018-05-23  ┆ 171   │
# │ 2018-07-29  ┆ 169   │
# └─────────────┴───────┘
# 2026-02-25 03:42:12,680-INFO-date_posted: 354 total rare categories
# 2026-02-25 03:42:12,680-INFO-The insights from the categorical data for the column date_posted have been obtained correctly
# 2026-02-25 03:42:12,680-WARNING-The plot for the column date_posted was not saved because save_plots is False
# 2026-02-25 03:42:12,682-INFO-Json report was written succesfully
# 2026-02-25 03:42:12,683-INFO-The file json_insights_2026-02-25.json was readed succesfully
# === AUTOMATED INSIGHTS REPORT ===
# Dataset: vehicles_us.csv
# Columns: ['price', 'model_year', 'model', 'condition', 'cylinders', 'fuel', 'odometer', 'transmission', 'type', 'paint_color', 'is_4wd', 'date_posted', 'days_listed']
#
# 1. 📈 DISTRIBUTION
# - price: media=12132.464919941776, median=9000.0, std=10040.803015443296, sesgo positive
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_price.html
# - model_year: media=2009.75046966977, median=2011.0, std=6.2820647921742045, sesgo negative
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_model_year.html
# - model:- unique values=100- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_model.html
# - model: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_model.html
# - condition:- unique values=6- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_condition.html
# - condition: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_condition.html
# - cylinders: media=6.125235058899817, median=6.0, std=1.6603600581926181, sesgo positive
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_cylinders.html
# - fuel:- unique values=5- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_fuel.html
# - fuel: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_fuel.html
# - odometer: media=115553.4617376756, median=113000.0, std=65094.611340709744, sesgo positive
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_odometer.html
# - transmission:- unique values=3- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_transmission.html
# - transmission: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_transmission.html
# - type:- unique values=13- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_type.html
# - type: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_type.html
# - paint_color:- unique values=13- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_paint_color.html
# - paint_color: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_paint_color.html
# - is_4wd: media=1.0, median=1.0, std=0.0, sesgo simetrico
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_is_4wd.html
# - date_posted:- unique values=354- Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_date_posted.html
# - date_posted: media=None, median=None, std=None, sesgo None
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_date_posted.html
# - days_listed: media=39.55475982532751, median=33.0, std=28.204269870578063, sesgo positive
# - Plot: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/distribution/distribution_days_listed.html
#
# 2. ⚠️ OUTLIERS
# - price: 1646 outliers -> (3.19%)
# - Sample: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/outliers/outliers_price.html
# - model_year: 709 outliers -> (1.38%)
# - Sample: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/outliers/outliers_model_year.html
# - The number of outliers is 0, so it is not necessary to make a boxplot for column cylinders
# - odometer: 487 outliers -> (0.95%)
# - Sample: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/outliers/outliers_odometer.html
# - The number of outliers is 0, so it is not necessary to make a boxplot for column is_4wd
# - days_listed: 1618 outliers -> (3.14%)
# - Sample: /home/arbolitos7/Documents/TripleTen/Sprint7/Sprint7/analysis_report/analysis_2026-02-25/outliers/outliers_days_listed.html
#
# 3. 🔗 CORRELATION
# - The correlation value is invalid. Correlation detected: The columns ['price', 'model_year', 'cylinders', 'odometer', 'is_4wd', 'days_listed'] have zero standard deviation or is zero
#
# 4. 🏷️ CATEGORIES
# - model: top lables= ['ford f-150', 'chevrolet silverado 1500', 'ram 1500', 'chevrolet silverado', 'jeep wrangler', 'ram 2500', 'toyota camry', 'honda accord', 'chevrolet silverado 2500hd', 'gmc sierra 1500']
# - model: 69 rare categories (<1.0%)
# - condition: top lables= ['excellent', 'good', 'like new', 'fair', 'new', 'salvage']
# - condition: 2 rare categories (<1.0%)
# - fuel: top lables= ['gas', 'diesel', 'hybrid', 'other', 'electric']
# - fuel: 3 rare categories (<1.0%)
# - transmission: top lables= ['automatic', 'manual', 'other']
# - transmission: 0 rare categories (<1.0%)
# - type: top lables= ['SUV', 'truck', 'sedan', 'pickup', 'coupe', 'wagon', 'mini-van', 'hatchback', 'van', 'convertible']
# - type: 4 rare categories (<1.0%)
# - paint_color: top lables= ['white', None, 'black', 'silver', 'grey', 'blue', 'red', 'green', 'brown', 'custom']
# - paint_color: 3 rare categories (<1.0%)
# - date_posted: top lables= ['2019-03-17', '2019-01-05', '2018-09-20', '2019-03-11', '2018-10-09', '2018-08-05', '2019-04-10', '2019-03-28', '2018-05-23', '2018-07-29']
# - date_posted: 354 rare categories (<1.0%)
